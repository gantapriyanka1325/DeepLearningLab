# %% [markdown]
# <a href="https://colab.research.google.com/github/gantapriyanka1325/DeepLearningLab/blob/main/program11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pickle
import numpy as np
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
with open("data_batch_1","rb") as f:
    batch=pickle.load(f,encoding='bytes')

# %%
x=batch[b'data']
y=np.array(batch[b'labels'])

# %%
x_images=x.reshape(-1,3,32,32).transpose(0,2,3,1).astype("float32")/255.0

# %%
y_cat=to_categorical(y,num_classes=10)

# %%
x_train,x_test,y_train,y_test=train_test_split(x_images,y_cat,test_size=0.2,random_state=42)
print("Data loaded:",x_train.shape,x_test.shape)
# Out:
# Data loaded: (8000, 32, 32, 3) (2000, 32, 32, 3)

# %%
from tensorflow.keras import layers,models
model_lenet=models.Sequential([
    layers.Conv2D(6,(5,5),activation='tanh',input_shape=(32,32,3),padding='same'),
    layers.AveragePooling2D(pool_size=(2,2)),
    layers.Conv2D(16,(5,5),activation='tanh'),
    layers.AveragePooling2D(pool_size=(2,2)),
    layers.Flatten(),
    layers.Dense(120,activation='tanh'),
    layers.Dense(84,activation='tanh'),
    layers.Dense(10,activation='softmax')

])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model_lenet.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_lenet.summary()
model_lenet.fit(x_train,y_train,epochs=5,batch_size=64,validation_data=(x_test,y_test))
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 6)      │           456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d               │ (None, 16, 16, 6)      │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 12, 12, 16)     │         2,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_1             │ (None, 6, 6, 16)       │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 576)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 120)            │        69,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 84)             │        10,164 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │           850 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 83,126 (324.71 KB)
#  Trainable params: 83,126 (324.71 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 12s 77ms/step - accuracy: 0.2205 - loss: 2.1117 - val_accuracy: 0.3330 - val_loss: 1.8384
# Epoch 2/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - accuracy: 0.3635 - loss: 1.8006 - val_accuracy: 0.3720 - val_loss: 1.7518
# Epoch 3/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 61ms/step - accuracy: 0.3863 - loss: 1.7451 - val_accuracy: 0.4090 - val_loss: 1.6932
# Epoch 4/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 77ms/step - accuracy: 0.4037 - loss: 1.7057 - val_accuracy: 0.4130 - val_loss: 1.6778
# Epoch 5/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 69ms/step - accuracy: 0.4052 - loss: 1.6645 - val_accuracy: 0.4215 - val_loss: 1.6534

# %%
model_alex=models.Sequential([
    layers.Conv2D(96,(3,3),activation='relu',input_shape=(32,32,3),padding='same'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(256,(3,3),activation='relu',padding='same'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(384,(3,3),activation='relu',input_shape=(32,32,3),padding='same'),
    layers.Conv2D(384,(3,3),activation='relu',input_shape=(32,32,3),padding='same'),
    layers.Conv2D(256,(3,3),activation='relu',input_shape=(32,32,3),padding='same'),
    layers.MaxPooling2D((2,2)),
    layers.Flatten(),
    layers.Dense(512,activation='relu'),
    layers.Dense(512,activation='relu'),
    layers.Dense(10,activation='softmax')

])

# %%
model_alex.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_alex.summary()
model_alex.fit(x_train,y_train,epochs=5,batch_size=64,validation_data=(x_test,y_test))
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 96)     │         2,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 96)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 256)    │       221,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 8, 8, 384)      │       885,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 8, 8, 384)      │     1,327,488 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 8, 8, 256)      │       884,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 512)            │     2,097,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,687,178 (21.69 MB)
#  Trainable params: 5,687,178 (21.69 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 342s 3s/step - accuracy: 0.1264 - loss: 2.2585 - val_accuracy: 0.3095 - val_loss: 1.9003
# Epoch 2/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 315s 3s/step - accuracy: 0.3066 - loss: 1.8700 - val_accuracy: 0.3935 - val_loss: 1.6149
# Epoch 3/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 316s 3s/step - accuracy: 0.4103 - loss: 1.5801 - val_accuracy: 0.4355 - val_loss: 1.5522
# Epoch 4/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 319s 3s/step - accuracy: 0.4648 - loss: 1.4318 - val_accuracy: 0.5065 - val_loss: 1.3487
# Epoch 5/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 313s 3s/step - accuracy: 0.5252 - loss: 1.2918 - val_accuracy: 0.5510 - val_loss: 1.2648

# %%
model_zf=models.Sequential([
    layers.Conv2D(96,(3,3),activation='relu',input_shape=(32,32,3),padding='same'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(256,(3,3),activation='relu',padding='same'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(384,(3,3),activation='relu',input_shape=(32,32,3),padding='same'),
    layers.Conv2D(384,(3,3),activation='relu',input_shape=(32,32,3),padding='same'),
    layers.Conv2D(256,(3,3),activation='relu',input_shape=(32,32,3),padding='same'),
    layers.MaxPooling2D((2,2)),
    layers.Flatten(),
    layers.Dense(512,activation='relu'),
    layers.Dense(512,activation='relu'),
    layers.Dense(10,activation='softmax')

])

# %%
model_zf.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_zf.summary()
model_zf.fit(x_train,y_train,epochs=5,batch_size=64,validation_data=(x_test,y_test))
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_7 (Conv2D)               │ (None, 32, 32, 96)     │         2,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 16, 16, 96)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 16, 16, 256)    │       221,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 8, 8, 384)      │       885,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 8, 8, 384)      │     1,327,488 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 8, 8, 256)      │       884,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 512)            │     2,097,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,687,178 (21.69 MB)
#  Trainable params: 5,687,178 (21.69 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 340s 3s/step - accuracy: 0.1355 - loss: 2.2447 - val_accuracy: 0.3250 - val_loss: 1.7875
# Epoch 2/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 318s 3s/step - accuracy: 0.3274 - loss: 1.7726 - val_accuracy: 0.3995 - val_loss: 1.5812
# Epoch 3/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 321s 3s/step - accuracy: 0.4160 - loss: 1.5573 - val_accuracy: 0.4550 - val_loss: 1.4319
# Epoch 4/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 340s 3s/step - accuracy: 0.4983 - loss: 1.3800 - val_accuracy: 0.5250 - val_loss: 1.3071
# Epoch 5/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 314s 3s/step - accuracy: 0.5473 - loss: 1.2337 - val_accuracy: 0.5410 - val_loss: 1.2732

# %%
model_vgg=models.Sequential([
    layers.Conv2D(64,(3,3),activation='relu',input_shape=(32,32,3),padding='same'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(128,(3,3),activation='relu',padding='same'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(256,(3,3),activation='relu',padding='same'),
    layers.Conv2D(256,(3,3),activation='relu',padding='same'),
    layers.MaxPooling2D((2,2)),
    layers.Flatten(),
    layers.Dense(512,activation='relu'),
    layers.Dense(512,activation='relu'),
    layers.Dense(10,activation='softmax')

])

# %%
model_vgg.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_vgg.summary()
model_vgg.fit(x_train,y_train,epochs=5,batch_size=64,validation_data=(x_test,y_test))
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_12 (Conv2D)              │ (None, 32, 32, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 8, 8, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 8, 8, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 512)            │     2,097,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,326,346 (12.69 MB)
#  Trainable params: 3,326,346 (12.69 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 114s 885ms/step - accuracy: 0.1696 - loss: 2.1844 - val_accuracy: 0.3240 - val_loss: 1.7406
# Epoch 2/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 116s 927ms/step - accuracy: 0.3406 - loss: 1.7475 - val_accuracy: 0.4290 - val_loss: 1.5113
# Epoch 3/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 139s 903ms/step - accuracy: 0.4187 - loss: 1.5237 - val_accuracy: 0.4430 - val_loss: 1.5053
# Epoch 4/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 109s 873ms/step - accuracy: 0.4939 - loss: 1.3576 - val_accuracy: 0.5205 - val_loss: 1.2806
# Epoch 5/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 119s 955ms/step - accuracy: 0.5635 - loss: 1.1814 - val_accuracy: 0.5620 - val_loss: 1.1999

# %%
from tensorflow.keras.layers import concatenate
def inception_module(x,filters):
    f1,f3r,f3,f5r,f5,fpp=filters
    path1=layers.Conv2D(f1,(1,1),activation='relu',padding='same')(x)
    path2=layers.Conv2D(f3r,(1,1),activation='relu',padding='same')(x)
    path2=layers.Conv2D(f3,(3,3),activation='relu',padding='same')(path2)
    path3=layers.Conv2D(f5r,(1,1),activation='relu',padding='same')(x)
    path3=layers.Conv2D(f5,(5,5),activation='relu',padding='same')(path3)
    path4=layers.MaxPooling2D((3,3),strides=(1,1), padding='same')(x)
    path4=layers.Conv2D(fpp,(1,1),activation='relu',padding='same')(path4)
    return concatenate([path1,path2,path3,path4],axis=-1)

# %%
input_layer=layers.Input(shape=(32,32,3))
x=inception_module(input_layer,[32,32,32,16,16,16])
x=layers.MaxPooling2D((2,2))(x)
x=inception_module(x,[64,48,64,16,32,32])
x=layers.GlobalAveragePooling2D()(x)
output=layers.Dense(10,activation='softmax')(x)
model_google=models.Model(input_layer,output)
model_google.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_google.summary()
model_google.fit(x_train,y_train,epochs=2,batch_size=64,validation_data=(x_test,y_test))

# %%
from tensorflow.keras import Model,Input
def res_block(x,filters):
    shortcut=x
    x=layers.Conv2D(filters,(3,3),padding='same',activation='relu')(x)
    x=layers.Conv2D(filters,(3,3),padding='same')(x)
    x=layers.add([shortcut,x])
    x=layers.Activation('relu')(x)
    return x



input_layer=Input(shape=(32,32,3))
x=layers.Conv2D(32,(3,3),activation='relu',padding='same')(input_layer)
x=res_block(x,32)
x=layers.MaxPooling2D((2,2))(x)
x=res_block(x,64)
x=layers.GlobalAveragePooling2D()(x)
output_layer=layers.Dense(10,activation='softmax')(x)

model_resnet=Model(inputs=input_layer,outputs=output_layer)
model_resnet.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_resnet.summary()
model_resnet.fit(x_train,y_train,epochs=5,batch_size=64,validation_data=(x_test,y_test))

# %%
input_layer=Input(shape=(32,32,3))
x=layers.Conv2D(32,(3,3),activation='relu',padding='same')(input_layer)
x=res_block(x,32)
x=layers.MaxPooling2D((2,2))(x)
x=res_block(x,64)
x=layers.GlobalAveragePooling2D()(x)
output=layers.Dense(10,activation='softmax')(x)

# %%
model_resnet=Model(inputs=input_layer,output=output)
model_resnet.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_resnet.summary()
model_resnet.fit(x_train,y_train,epochs=2,batch_size=64,validation_data=(x_test,y_test))
